# %%
import pandas as pd
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Serial Number                                            Content  \
# 0              1  "Sorry, if you come you will be immediately se...
# 1              2                   "See you on Friday...Big Crowd!
# 2              3                                            "True!
# 3              4                                    "“NO PRESSURE”"
# 4              5                                   "Will be Great!
#
#       User_Id         Username  Label
# 0  "25073877"  realdonaldtrump      1
# 1  "25073877"  realdonaldtrump      1
# 2  "25073877"  realdonaldtrump      1
# 3  "25073877"  realdonaldtrump      1
# 4  "25073877"  realdonaldtrump      1

# %%
df = df[pd.notnull(df['Content'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106514 entries, 0 to 106513
# Data columns (total 5 columns):
# Serial Number    106514 non-null int64
# Content          106514 non-null object
# User_Id          106514 non-null object
# Username         106514 non-null object
# Label            106514 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 4.9+ MB

# %%
col = ['Username', 'Content']
df = df[col]

# %%
df.columns
# Out:
# Index(['Username', 'Content'], dtype='object')

# %%
df.columns = ['Username', 'Content']

# %%
df['Label'] = df['Username'].factorize()[0]
from io import StringIO
category_id_df = df[['Username', 'Label']].drop_duplicates().sort_values('Label')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['Label', 'Username']].values)

# %%
df
# Out:
#                Username                                            Content  \
# 0       realdonaldtrump  "Sorry, if you come you will be immediately se...
# 1       realdonaldtrump                   "See you on Friday...Big Crowd!
# 2       realdonaldtrump                                            "True!
# 3       realdonaldtrump                                    "“NO PRESSURE”"
# 4       realdonaldtrump                                   "Will be Great!
# ...                 ...                                                ...
# 106509              cnn  "A rafflesia that recently bloomed in a West S...
# 106510              cnn  "Kentucky's Attorney General says he's asking ...
# 106511              cnn  "The American Kennel Club has announced two ne...
# 106512              cnn  "Google has disabled access of Xiaomi devices ...
# 106513              cnn  "Republican Sen. Lindsey Graham of South Carol...
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 106509     49
# 106510     49
# 106511     49
# 106512     49
# 106513     49
#
# [106514 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(df.Content).toarray()
labels = df.Label
features.shape
# Out:
# (106514, 33416)

# %%
from sklearn.feature_selection import chi2
import numpy as np

N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Product))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'akshaykumar':
#   . Most correlated unigrams:
#        . thebalachallenge
#        . thank
#   . Most correlated bigrams:
#        . kareenakapoorkhan diljitdosanjh
#        . diljitdosanjh advani_kiara
# # 'arianagrande':
#   . Most correlated unigrams:
#        . thankunext
#        . love
#   . Most correlated bigrams:
#        . thank thankunext
#        . love sm
# # 'barackobama':
#   . Most correlated unigrams:
#        . president
#        . obama
#   . Most correlated bigrams:
#        . live president
#        . president obama
# # 'bbcbreaking':
#   . Most correlated unigrams:
#        . brexit
#        . uk
#   . Most correlated bigrams:
#        . died aged
#        . uk pm
# # 'beingsalmankhan':
#   . Most correlated unigrams:
#        . ho
#        . uniform
#   . Most correlated bigrams:
#        . remember need
#        . country jai
# # 'billgates':
#   . Most correlated unigrams:
#        . melinda
#        . polio
#   . Most correlated bigrams:
#        . bit ly
#        . http bit
# # 'britneyspears':
#   . Most correlated unigrams:
#        . xo
#        . pieceofme
#   . Most correlated bigrams:
#        . pieceofme shows
#        . tonight pieceofme
# # 'brunomars':
#   . Most correlated unigrams:
#        . 24kmagicworldtour
#        . hooligans
#   . Most correlated bigrams:
#        . night 24kmagicworldtour
#        . fuckin guy
# # 'cnn':
#   . Most correlated unigrams:
#        . trial
#        . according
#   . Most correlated bigrams:
#        . senate impeachment
#        . impeachment trial
# # 'cnnbrk':
#   . Most correlated unigrams:
#        . says
#        . updates
#   . Most correlated bigrams:
#        . follow live
#        . live updates
# # 'cristiano':
#   . Most correlated unigrams:
#        . cr7
#        . cristiano
#   . Most correlated bigrams:
#        . http say
#        . say ly
# # 'drake':
#   . Most correlated unigrams:
#        . ovoxo
#        . ovo
#   . Most correlated bigrams:
#        . ovo sound
#        . club paradise
# # 'espn':
#   . Most correlated unigrams:
#        . thecheckdown
#        . lebron
#   . Most correlated bigrams:
#        . ago today
#        . fantasyfocus crew
# # 'fcbarcelona':
#   . Most correlated unigrams:
#        . messi
#        . barça
#   . Most correlated bigrams:
#        . camp nou
#        . leo messi
# # 'harry_styles':
#   . Most correlated unigrams:
#        . calaurand
#        . xx
#   . Most correlated bigrams:
#        . thanks having
#        . live tour
# # 'iamsrk':
#   . Most correlated unigrams:
#        . raees
#        . thank
#   . Most correlated bigrams:
#        . ha ha
#        . thank ur
# # 'imvkohli':
#   . Most correlated unigrams:
#        . fcgoaofficial
#        . staywrogn
#   . Most correlated bigrams:
#        . series win
#        . jai hind
# # 'instagram':
#   . Most correlated unigrams:
#        . weeklyfluff
#        . theweekoninstagram
#   . Most correlated bigrams:
#        . hashtag project
#        . weekend hashtag
# # 'jimmyfallon':
#   . Most correlated unigrams:
#        . stops
#        . fallontonight
#   . Most correlated bigrams:
#        . thankyounotefriday fallontonight
#        . tweets fallontonight
# # 'jlo':
#   . Most correlated unigrams:
#        . shadesofblue
#        . worldofdance
#   . Most correlated bigrams:
#        . tonight nbcworldofdance
#        . nbcworldofdance worldofdance
# # 'jtimberlake':
#   . Most correlated unigrams:
#        . cantstopthefeeling
#        . teamjt
#   . Most correlated bigrams:
#        . jt2020tour http
#        . the2020experience 2of2
# # 'justinbieber':
#   . Most correlated unigrams:
#        . whatdoyoumean
#        . purpose
#   . Most correlated bigrams:
#        . http zwmjvgsrpv
#        . whatdoyoumean http
# # 'katyperry':
#   . Most correlated unigrams:
#        . kpcollections
#        . americanidol
#   . Most correlated bigrams:
#        . days cozy
#        . witness tour
# # 'kevinhart4real':
#   . Most correlated unigrams:
#        . harts
#        . irresponsibletour
#   . Most correlated bigrams:
#        . irresponsibletour comedicrockstarshit
#        . let gooooooooo
# # 'kimkardashian':
#   . Most correlated unigrams:
#        . skims
#        . kkwbeauty
#   . Most correlated bigrams:
#        . sunday service
#        . 12pm pst
# # 'kingjames':
#   . Most correlated unigrams:
#        . theland
#        . striveforgreatness
#   . Most correlated bigrams:
#        . yes sir
#        . striveforgreatness http
# # 'ladygaga':
#   . Most correlated unigrams:
#        . gaga
#        . joanne
#   . Most correlated bigrams:
#        . little monsters
#        . lady gaga
# # 'liampayne':
#   . Most correlated unigrams:
#        . bedroomfloor
#        . stripthatdown
#   . Most correlated bigrams:
#        . 55 playlist
#        . jonasblue lennonstella
# # 'liltunechi':
#   . Most correlated unigrams:
#        . luv
#        . pack
#   . Most correlated bigrams:
#        . green yellow
#        . red sox
# # 'louis_tomlinson':
#   . Most correlated unigrams:
#        . lad
#        . xfactor
#   . Most correlated bigrams:
#        . loads love
#        . big love
# # 'mileycyrus':
#   . Most correlated unigrams:
#        . nbcthevoice
#        . teammiley
#   . Most correlated bigrams:
#        . fuck yeah
#        . vote teammiley
# # 'narendramodi':
#   . Most correlated unigrams:
#        . bjp
#        . india
#   . Most correlated bigrams:
#        . west bengal
#        . watch speech
# # 'nasa':
#   . Most correlated unigrams:
#        . moon
#        . space_station
#   . Most correlated bigrams:
#        . artemis program
#        . spacex dragon
# # 'neymarjr':
#   . Most correlated unigrams:
#        . gagamilanoworld
#        . só
#   . Most correlated bigrams:
#        . só falta
#        . ganhar carro
# # 'niallofficial':
#   . Most correlated unigrams:
#        . flicker
#        . askniall
#   . Most correlated bigrams:
#        . slow hands
#        . meet ya
# # 'nytimes':
#   . Most correlated unigrams:
#        . opinion
#        . writes
#   . Most correlated bigrams:
#        . breaking news
#        . briefing need
# # 'oprah':
#   . Most correlated unigrams:
#        . greenleaf
#        . supersoulsunday
#   . Most correlated bigrams:
#        . oprah belief
#        . 10 9c
# # 'pink':
#   . Most correlated unigrams:
#        . justlikefire
#        . thankyou
#   . Most correlated bigrams:
#        . hurts 2b
#        . 2b human
# # 'realdonaldtrump':
#   . Most correlated unigrams:
#        . foxnews
#        . democrats
#   . Most correlated bigrams:
#        . fake news
#        . witch hunt
# # 'realmadrid':
#   . Most correlated unigrams:
#        . rmliga
#        . halamadrid
#   . Most correlated bigrams:
#        . rmcity halamadrid
#        . rmliga halamadrid
# # 'rihanna':
#   . Most correlated unigrams:
#        . http
#        . fentybeauty
#   . Most correlated bigrams:
#        . diamondsworldtour http
#        . gt http
# # 'selenagomez':
#   . Most correlated unigrams:
#        . fb
#        . http
#   . Most correlated bigrams:
#        . http fb
#        . photo http
# # 'shakira':
#   . Most correlated unigrams:
#        . shakhq
#        . shak
#   . Most correlated bigrams:
#        . shak new
#        . el dorado
# # 'sportscenter':
#   . Most correlated unigrams:
#        . nfl
#        . sctop10
#   . Most correlated bigrams:
#        . capitalone fan
#        . lamar jackson
# # 'srbachchan':
#   . Most correlated unigrams:
#        . हम
#        . ef
#   . Most correlated bigrams:
#        . ef हम
#        . अन अन
# # 'taylorswift13':
#   . Most correlated unigrams:
#        . reputaylurking
#        . reputation
#   . Most correlated bigrams:
#        . need calm
#        . reputaylurking reputation
# # 'theellenshow':
#   . Most correlated unigrams:
#        . thankssponsor
#        . gameofgames
#   . Most correlated bigrams:
#        . jennifer aniston
#        . happy birthday
# # 'twitter':
#   . Most correlated unigrams:
#        . dm
#        . notifications
#   . Most correlated bigrams:
#        . need talk
#        . day time
# # 'wizkhalifa':
#   . Most correlated unigrams:
#        . roll
#        . flytimes
#   . Most correlated bigrams:
#        . roll day
#        . day started
# # 'youtube':
#   . Most correlated unigrams:
#        . creators
#        . youtube
#   . Most correlated bigrams:
#        . featured creator
#        . today featured

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

X_train, X_test, y_train, y_test = train_test_split(df['Content'], df['Username'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
X_test_counts = count_vect.fit_transform(X_test)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_test_tfidf = tfidf_transformer.fit_transform(X_test_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["Sorry, if you come you will be immediately sent back! "])))
# Out:
# ['theellenshow']

# %%
print(clf.predict(count_vect.transform(["I am disputing the inaccurate information the Chex-Systems has on my credit report. I initially submitted a police report on XXXX/XXXX/16 and Chex Systems only deleted the items that I mentioned in the letter and not all the items that were actually listed on the police report. In other words they wanted me to say word for word to them what items were fraudulent. The total disregard of the police report and what accounts that it states that are fraudulent. If they just had paid a little closer attention to the police report I would not been in this position now and they would n't have to research once again. I would like the reported information to be removed : XXXX XXXX XXXX"])))
# Out:
# ['cnn']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_score


models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
cv_df
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
#                 model_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.182705
# 1   RandomForestClassifier         1  0.192849
# 2   RandomForestClassifier         2  0.226046
# 3   RandomForestClassifier         3  0.204058
# 4   RandomForestClassifier         4  0.205647
# 5                LinearSVC         0  0.479835
# 6                LinearSVC         1  0.562922
# 7                LinearSVC         2  0.575935
# 8                LinearSVC         3  0.567182
# 9                LinearSVC         4  0.535191
# 10           MultinomialNB         0  0.440818
# 11           MultinomialNB         1  0.510604
# 12           MultinomialNB         2  0.527252
# 13           MultinomialNB         3  0.522284
# 14           MultinomialNB         4  0.482945
# 15      LogisticRegression         0  0.468533
# 16      LogisticRegression         1  0.552036
# 17      LogisticRegression         2  0.566405
# 18      LogisticRegression         3  0.551825
# 19      LogisticRegression         4  0.518606

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
